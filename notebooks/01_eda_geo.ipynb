# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('seaborn-v0_8')
# %matplotlib inline

# Agregar src al path
repo_root = Path.cwd().resolve()
src_path = repo_root / 'src'
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# %%
from utils_spatial import validate_columns

# Cargar datos de ejemplo
data_path = Path('data_sample') / 'sample_drillholes.csv'
df = pd.read_csv(data_path)

# Validar columnas esperadas
required_cols = ['X', 'Y', 'Z', 'grade', 'domain', 'lithology']
validate_columns(df, required_cols)
df.head()

# %%
from eda_geo import basic_stats, plot_grade_histogram, plot_xy_scatter

stats = basic_stats(df, value_col='grade')
stats

# %%
plot_grade_histogram(df, value_col='grade')
plot_xy_scatter(df, x_col='X', y_col='Y', value_col='grade')
