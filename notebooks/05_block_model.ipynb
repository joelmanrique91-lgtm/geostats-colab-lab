# %% [markdown]
# # 05_block_model
#
# Secuencia automatizada del pipeline geoestadístico.

# %%
import sys

sys.path.append("src")
import geostats_pipeline as gp

config_path = "config/project.json"
cfg = gp.load_config(config_path)

# %%
artifacts = gp.run_block_model(cfg, output_dir="outputs")
manifest_path = gp.get_manifest_path("outputs")
gp.register_manifest(manifest_path, "05_block_model", artifacts, metadata={"config_path": config_path})
