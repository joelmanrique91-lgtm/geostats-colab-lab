# %% [markdown]
# # 08_uncertainty_simulation
#
# Secuencia automatizada del pipeline geoestadístico.

# %%
import sys

sys.path.append("src")
import geostats_pipeline as gp

config_path = "config/project.json"
cfg = gp.load_config(config_path)

# %%
artifacts = gp.run_uncertainty_simulation(cfg, output_dir="outputs")
manifest_path = gp.get_manifest_path("outputs")
gp.register_manifest(manifest_path, "08_uncertainty_simulation", artifacts, metadata={"config_path": config_path})
