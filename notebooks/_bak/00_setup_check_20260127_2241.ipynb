# %% [markdown]
# # 00 - Setup check
# Verifica entorno, paths y CSVs disponibles.

# %%
import os, sys, json

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir(PROJECT_ROOT)
else:
    PROJECT_ROOT = os.getcwd()

sys.path.insert(0, PROJECT_ROOT)

# %%
from src.io_utils import find_csv_files
from src.make_demo_data import make_demo_csv

cfg_path = "config/project.json"
print("Config:", os.path.abspath(cfg_path))
with open(cfg_path, "r", encoding="utf-8") as f:
    cfg = json.load(f)

print("CSV path:", cfg["data_csv_path"])
if not os.path.exists(cfg["data_csv_path"]):
    make_demo_csv(cfg["data_csv_path"])

print("CSV files:", find_csv_files("csv"))
# Out:
# Config: c:\Users\joelm\Documents\geostats\config\project.json
# CSV path: csv/Conminution.csv
# CSV files: ['csv\\Conminution.csv']
